# %% [markdown]
# ## Load the First Phase csv file. This is with F-PKI csv

# %%
import pandas as pd
kf = pd.read_csv('First phase.csv')

# %%
kf
# Out:
#                 Website  Connection Establishment Time        RTT  \
# 0            google.com                     140.879154  45.387030
# 1          facebook.com                     132.058382  50.455570
# 2            amazon.com                     485.580206  47.918558
# 3              imdb.com                     483.942270  45.447350
# 4             apple.com                     171.164274  45.466900
# ...                 ...                            ...        ...
# 5895  stackoverflow.com                     126.820564  37.778378
# 5896     calculator.net                     426.192760  37.413120
# 5897           usps.com                            NaN        NaN
# 5898        www2.hm.com                      99.035740  40.137768
# 5899        grubhub.com                      90.323448  38.143635
#
#       Initial Response    Latency  Page Load Time  Dependency Load Time  \
# 0                107.0  22.693515          2606.0                 981.0
# 1                239.0  25.227785          2166.0                1904.0
# 2                205.0  23.959279          1897.0                 795.0
# 3               1264.0  22.723675          4479.0                2425.0
# 4                 91.0  22.733450          2072.0                 712.0
# ...                ...        ...             ...                   ...
# 5895             156.0  18.889189          1035.0                 802.0
# 5896             144.0  18.706560          1035.0                 768.0
# 5897               NaN        NaN             NaN                   NaN
# 5898              63.0  20.068884          1540.0                1104.0
# 5899              39.0  19.071817           801.0                 320.0
#
#       Page Size              IP    City  Country  \
# 0        5758.0  31.171.155.229  Tirana  Albania
# 1       67307.0  31.171.155.229  Tirana  Albania
# 2        7027.0  31.171.155.229  Tirana  Albania
# 3      707806.0  31.171.155.229  Tirana  Albania
# 4      255185.0  31.171.155.229  Tirana  Albania
# ...         ...             ...     ...      ...
# 5895   175989.0    45.84.39.119    Oslo   Norway
# 5896    11466.0    45.84.39.119    Oslo   Norway
# 5897        NaN    45.84.39.119    Oslo   Norway
# 5898   807568.0    45.84.39.119    Oslo   Norway
# 5899     2701.0    45.84.39.119    Oslo   Norway
#
#                                  WASM RTT  \
# 0                                      44
# 1                                      46
# 2         Waiting time exceeds 10 seconds
# 3     No WASM RTT,duration or sizes found
# 4                                      46
# ...                                   ...
# 5895                                  396
# 5896      Waiting time exceeds 10 seconds
# 5897                                  NaN
# 5898                                   39
# 5899                                   38
#
#                            WASM Durations  \
# 0                                     810
# 1                                    3707
# 2         Waiting time exceeds 10 seconds
# 3     No WASM RTT,duration or sizes found
# 4                                     298
# ...                                   ...
# 5895                                 2070
# 5896      Waiting time exceeds 10 seconds
# 5897                                  NaN
# 5898                                  480
# 5899                                  249
#
#                                WASM Sizes            Website Type
# 0                                 3131021                   Other
# 1                                18162816      Social Media Sites
# 2         Waiting time exceeds 10 seconds    E-commerce Platforms
# 3     No WASM RTT,duration or sizes found  Entertainment Websites
# 4                                   86533                   Other
# ...                                   ...                     ...
# 5895                              1836087                   Other
# 5896      Waiting time exceeds 10 seconds                   Other
# 5897                                  NaN                   Other
# 5898                               362846                   Other
# 5899                                78105                   Other
#
# [5900 rows x 15 columns]

# %% [markdown]
# ## 6 block website remove from data set

# %%
kf2  =  kf[kf['Website'] !='playstation.com']

# %%
kf3  =  kf2[kf2['Website'] !='samsung.com']

# %%
kf4  =  kf3[kf3['Website'] !='usps.com']

# %%
kf5  =  kf4[kf4['Website'] !='adidas.com']

# %%
kf6  =  kf5[kf5['Website'] !='friv.com']

# %%
kf7  =  kf6[kf6['Website'] !='usnews.com']

# %%
kf7.to_csv("1stwithoutsixwebsite.csv")

# %% [markdown]
# ##  As case 1 is proper JSON we remove the all other extension cases (2/3/4) from dataset

# %%
import pandas as pd

df = pd.read_csv('1stwithoutsixwebsite.csv')

# %%
df2  =  df[df['WASM RTT'] !='No WASM RTT,duration or sizes found']

# %%
df3 =  df2[df2['WASM RTT'] !='Waiting time exceeds 10 seconds']

# %%
df4  =  df3[df3['WASM RTT'] !='0']

# %%
df5 = df4.dropna()

# %%
df5.to_csv("new_case1_all_rtt_size_duration.csv")

# %% [markdown]
# ## Below script merge the clean First phase (new_case1_all_rtt_size_duration) csv file with Third phase csv. Third phase csv file contain without F-PKI dataset

# %%
import pandas as pd


df1 = pd.read_csv('new_case1_all_rtt_size_duration.csv')
df2 = pd.read_csv('Third phase.csv')

merged_df = pd.merge(df1, df2, on=['Website', 'Country'])
merged_df.to_csv('nowasmrttsizes10merged.csv', index=False)

# %% [markdown]
# ## Below script helps to show from 94 websites how many unique websites show Case 1 behaviour

# %%
import pandas as pd

df = pd.read_csv('nowasmrttsizes10merged.csv')

unique_websites = df['Website'].unique()
num_unique_websites = len(unique_websites)

print("Unique Websites:")
for website in unique_websites:
    print(website)
print(f"Total Unique Websites: {num_unique_websites}")
# Out:
# Unique Websites:
# google.com
# facebook.com
# apple.com
# yelp.com
# dictionary.com
# britannica.com
# weather.com
# walmart.com
# espncricinfo.com
# webmd.com
# thesaurus.com
# whatsapp.com
# rottentomatoes.com
# bbc.com
# healthline.com
# netflix.com
# indeed.com
# thefreedictionary.com
# spotify.com
# ytmp3.cc
# nih.gov
# tiktok.com
# cdc.gov
# blog.google
# indiatimes.com
# speedtest.net
# ssyoutube.com
# unsplash.com
# mcdonalds.com
# bloomberg.com
# forbes.com
# booking.com
# xhamster.com
# spanishdict.com
# goodhousekeeping.com
# dominos.com
# twitch.tv
# pexels.com
# poki.com
# caranddriver.com
# globo.com
# theguardian.com
# expedia.com
# realtor.com
# crazygames.com
# digitaltrends.com
# nintendo.com
# decathlon.com
# amazon.com
# imdb.com
# pinterest.com
# wiktionary.org
# yahoo.com
# espn.com
# linkedin.com
# mayoclinic.org
# cricbuzz.com
# timeanddate.com
# bestbuy.com
# xvideos.com
# livescore.com
# ebay.com
# pornhub.com
# steampowered.com
# investopedia.com
# nordstrom.com
# cnbc.com
# roblox.com
# flashscore.com
# vocabulary.com
# xe.com
# coinmarketcap.com
# github.com
# hotels.com
# wellsfargo.com
# nba.com
# akc.org
# fast.com
# stackoverflow.com
# www2.hm.com
# grubhub.com
# merriam-webster.com
# homedepot.com
# adobe.com
# gsmarena.com
# lowes.com
# craigslist.org
# deepl.com
# xnxx.com
# tripadvisor.com
# cambridge.org
# Total Unique Websites: 91
